# %% [markdown]
# <a href="https://colab.research.google.com/github/swaroopkasaraneni/PythonProgramming/blob/main/DevelopingWebCase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Display first 100 records from the data and play with parameters -tiles, zoom_start etc. Map will be saved in BasicWebMap.html –view it in browser

# %%
import folium
import pandas as pd


data = pd.read_csv('/content/Police_Department_Incidents_Year_2016_.csv')


first_100 = data.head(100)
map_center = [first_100['X'].mean(), first_100['Y'].mean()]
m = folium.Map(location=map_center, zoom_start=12)

folium.TileLayer('OpenStreetMap').add_to(m)

for index, row in first_100.iterrows():
    folium.Marker(
        location=[row['X'], row['Y']],
        popup=row['Category']
    ).add_to(m)

m.save("BasicWebMap.html")

print("Map has been saved as BasicWebMap.html.")
# Out:
# Map has been saved as BasicWebMap.html.

# %% [markdown]
# 2.For latest 7 days of data create WebMap of Crimes which are categorized as ROBBERY

# %%
import folium
import pandas as pd


data = pd.read_csv('/content/Police_Department_Incidents_Year_2016_.csv')

data['Date'] = pd.to_datetime(data['Date'])
unique_dates = data['Date'].dt.date.unique()
sorted_unique_dates = sorted(unique_dates)
last_7_unique_dates = sorted_unique_dates[-7:]
print(last_7_unique_dates)

robbery_data = data[(data['Category'] == 'ROBBERY') & (data['Date'].dt.date.isin(last_7_unique_dates))]

map_center = [robbery_data['X'].mean(), robbery_data['Y'].mean()]
m = folium.Map(location=map_center, zoom_start=12)

# Add markers for each robbery
for _, row in robbery_data.iterrows():
    folium.Marker(
        location=[row['X'], row['Y']],
        popup=f"Date: {row['Date']}<br>Category: {row['Category']}",
        icon=folium.Icon(color='red', icon='info-sign')
    ).add_to(m)

m
# Out:
# <ipython-input-17-6e536738c201>:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date'] = pd.to_datetime(data['Date'])
# [datetime.date(2016, 12, 25), datetime.date(2016, 12, 26), datetime.date(2016, 12, 27), datetime.date(2016, 12, 28), datetime.date(2016, 12, 29), datetime.date(2016, 12, 30), datetime.date(2016, 12, 31)]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
# ...

# %% [markdown]
# 3.For latest 15 days of data create One WebMap of Crimes which are categorized as FRAUD and GAMBLING. Change the icon to font awesome icon (http://fontawesome.io/icons/)

# %%
import folium
import pandas as pd


data = pd.read_csv('/content/Police_Department_Incidents_Year_2016_.csv')

data['Date'] = pd.to_datetime(data['Date'])
unique_dates = data['Date'].dt.date.unique()
sorted_unique_dates = sorted(unique_dates)
last_15_unique_dates = sorted_unique_dates[-15:]
print(last_15_unique_dates)

filtered_data = data[(data['Category'].isin(['FRAUD', 'GAMBLING'])) & (data['Date'].dt.date.isin(last_15_unique_dates))]

map_center = [filtered_data['X'].mean(), filtered_data['Y'].mean()]
m = folium.Map(location=map_center, zoom_start=12,tiles="OpenStreetMap")

icon_fraud = 'money-bill'
icon_gambling = 'cogs'

# Add markers for each robbery
for _, row in filtered_data.iterrows():
    icon = icon_fraud if row['Category'] == 'FRAUD' else icon_gambling
    color = 'red' if row['Category'] == 'FRAUD' else 'blue'
    folium.Marker(
        location=[row['X'], row['Y']],
        popup=f"Date: {row['Date']}<br>Category: {row['Category']}",
        icon=folium.Icon(icon=icon, prefix='fa', color= color)
    ).add_to(m)


m
# Out:
# <ipython-input-22-d118bff5fe5d>:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date'] = pd.to_datetime(data['Date'])
# [datetime.date(2016, 12, 17), datetime.date(2016, 12, 18), datetime.date(2016, 12, 19), datetime.date(2016, 12, 20), datetime.date(2016, 12, 21), datetime.date(2016, 12, 22), datetime.date(2016, 12, 23), datetime.date(2016, 12, 24), datetime.date(2016, 12, 25), datetime.date(2016, 12, 26), datetime.date(2016, 12, 27), datetime.date(2016, 12, 28), datetime.date(2016, 12, 29), datetime.date(2016, 12, 30), datetime.date(2016, 12, 31)]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
# ...

# %% [markdown]
# 4.BONUS ASSIGNMENT--Displayheatmap for Divvy Bikes.  Divvy Bikes runs bike rental service in Chicago and their bike station geolocation data is shared. Refer to BikesHeatMap.py and Divvy_Stations_2016_Q3.csv, Divvy_Stations_2016_Q4.csv

# %% [markdown]
# Enhancements for code
# 1. Lot of visual options are available to change the map. You can refer to https://python-visualization.github.io/folium/modules.html for options

# %%
from folium.plugins import HeatMap
locations = [[37.775420, -122.403404], [37.775450, -122.403409], [37.774910, -122.403410]]
HeatMap(locations).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# 2.Change the code to create webmap for 'BURGALRY ' for last 7 days

# %%
import folium
import pandas as pd


data = pd.read_csv('/content/Police_Department_Incidents_Year_2016_.csv')

data['Date'] = pd.to_datetime(data['Date'])
unique_dates = data['Date'].dt.date.unique()
sorted_unique_dates = sorted(unique_dates)
last_7_unique_dates = sorted_unique_dates[-7:]
print(last_7_unique_dates)

robbery_data = data[(data['Category'] == 'BURGALRY') & (data['Date'].dt.date.isin(last_7_unique_dates))]

x_mean = robbery_data['X'].mean()
if pd.isna(x_mean):
    x_mean = 0

y_mean = robbery_data['Y'].mean()
if pd.isna(y_mean):
    y_mean = 0

map_center = [x_mean,y_mean]
m = folium.Map(location=map_center, zoom_start=12)

# Add markers for each robbery
for _, row in robbery_data.iterrows():
    folium.Marker(
        location=[row['X'], row['Y']],
        popup=f"Date: {row['Date']}<br>Category: {row['Category']}",
        icon=folium.Icon(color='red', icon='info-sign')
    ).add_to(m)

m
# Out:
# <ipython-input-20-4924d1242b04>:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date'] = pd.to_datetime(data['Date'])
# [datetime.date(2016, 12, 25), datetime.date(2016, 12, 26), datetime.date(2016, 12, 27), datetime.date(2016, 12, 28), datetime.date(2016, 12, 29), datetime.date(2016, 12, 30), datetime.date(2016, 12, 31)]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
# ...

# %% [markdown]
# 3.BONUS ASSIGNMENT–Uncomment the code see the changes
